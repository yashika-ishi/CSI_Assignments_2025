# %% [markdown]
# <a href="https://colab.research.google.com/github/yashika-ishi/CSI_Assignments_2025/blob/main/Week4_Assignment_Exploratory_Data_Analysis_(EDA).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Celebal Technologies**
# *Celebel Summer Internship (CSI)*
# <br>
# WEEK-4
# <br>
# Assignment : Exploratory Data Analysis (EDA)
# <br>
# Description:
# <br>
# 1. Conduct an in-depth Exploratory Data Analysis on a complex dataset. Focus on understanding data distributions, identifying missing values, detecting outliers, and uncovering relationships between variables. Utilize visualizations like histograms, box plots, and heatmaps to support your findings.
#     <br>Resources :<br>
#     https://www.kaggle.com/code/junaiddata35/titanic-dataset-exploratory-data-analysis-eda
#
#  DATASET: Titanic_Dataset (https://github.com/yashika-ishi/CSI_Assignments_2025/blob/main/Titanic_Dataset.csv)
#
# ***By: Yashika***

# %% [markdown]
# # **Step 1: Importing Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Step 2: Load the Dataset**

# %%
# Settings for better visuals
sns.set(style='whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)

# Loading the Dataset
df = pd.read_csv('/content/drive/MyDrive/CSI DATASETS/Titanic_Dataset.csv')
print("First 5 rows of the dataset:")
print(df.head())
# Out:
# First 5 rows of the dataset:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %% [markdown]
# # **Step 3: Dataset Overview**

# %%
print("\nDataset Shape:", df.shape)
print("\nDataset Info:")
df.info()
# Out:
# Dataset Shape: (891, 12)
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # **Step 4: Check for Missing Values**

# %%
print("\nMissing Values in Each Column:")
print(df.isnull().sum())
# Out:
# Missing Values in Each Column:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # **Step 5: Impute Missing Values**

# %%
# Fill missing 'Age' values with the median age
df['Age'] = df['Age'].fillna(df['Age'].median())

# Fill missing 'Embarked' values with the most frequent value (mode)
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# Fill missing 'Cabin' values with 'Unknown'
df['Cabin'] = df['Cabin'].fillna('Unknown')

# Verify again - print missing values in each column after imputation
print("\nMissing Values in Each Column (After Imputation):")
print(df.isnull().sum())
# Out:
# Missing Values in Each Column (After Imputation):
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# # **Step 6: Statistical Summary**

# %%
print("\nSummary Statistics:")
print(df.describe(include='all'))
# Out:
# Summary Statistics:
#         PassengerId    Survived      Pclass                 Name   Sex  \
# count    891.000000  891.000000  891.000000                  891   891
# unique          NaN         NaN         NaN                  891     2
# top             NaN         NaN         NaN  Dooley, Mr. Patrick  male
# freq            NaN         NaN         NaN                    1   577
# mean     446.000000    0.383838    2.308642                  NaN   NaN
# std      257.353842    0.486592    0.836071                  NaN   NaN
# min        1.000000    0.000000    1.000000                  NaN   NaN
# 25%      223.500000    0.000000    2.000000                  NaN   NaN
# 50%      446.000000    0.000000    3.000000                  NaN   NaN
# 75%      668.500000    1.000000    3.000000                  NaN   NaN
# max      891.000000    1.000000    3.000000                  NaN   NaN
#
#                Age       SibSp       Parch  Ticket        Fare    Cabin  \
# ...

# %% [markdown]
# # **Step 7: Univariate Analysis**

# %%
# Survival Count Distribution
sns.countplot(x='Survived', data=df, hue=None)  # Removed palette warning
plt.title('Survival Distribution (0 = No, 1 = Yes)')
plt.xlabel('Survived')
plt.ylabel('Count')
plt.show()

# Passenger Class Distribution
sns.countplot(x='Pclass', data=df, hue=None)  # Removed palette warning
plt.title('Passenger Class Distribution')
plt.xlabel('Pclass')
plt.ylabel('Count')
plt.show()

# Gender Distribution
sns.countplot(x='Sex', data=df, hue=None)  # Removed palette warning
plt.title('Gender Distribution')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.show()

# Age Distribution Histogram with KDE
sns.histplot(df['Age'].dropna(), bins=20, kde=True, color='skyblue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# Fare Distribution Boxplot (Outlier Detection)
sns.boxplot(y='Fare', data=df, color='lightgreen')
plt.title('Fare Boxplot (Detecting Outliers)')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# # **Step 8: Bivariate Analysis**

# %%
# Survival by Gender
sns.countplot(x='Sex', hue='Survived', data=df, palette='coolwarm')
plt.title('Survival Count by Gender')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.legend(title='Survived')
plt.show()

# Survival by Passenger Class
sns.countplot(x='Pclass', hue='Survived', data=df, palette='Set3')
plt.title('Survival Count by Class')
plt.xlabel('Pclass')
plt.ylabel('Count')
plt.legend(title='Survived')
plt.show()

# Survival by Embarkation Port
sns.countplot(x='Embarked', hue='Survived', data=df, palette='Set1')
plt.title('Survival Count by Embarkation Port')
plt.xlabel('Embarked')
plt.ylabel('Count')
plt.legend(title='Survived')
plt.show()

# Age vs Survival using Violin Plot
sns.violinplot(x='Survived', y='Age', data=df)  # Removed palette to suppress future warning
plt.title('Age Distribution by Survival')
plt.xlabel('Survived')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# # **Step 9: Correlation Analysis**

# %%
# Compute correlation matrix
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# # **Step 10: Feature Engineering**

# %%
# Create FamilySize Feature
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1

# Extract Title from Name
df['Title'] = df['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)

# Create Age Groups
df['AgeGroup'] = pd.cut(df['Age'], bins=[0, 12, 20, 40, 60, 100],
                        labels=['Child', 'Teen', 'Adult', 'Middle-Aged', 'Senior'])

# %% [markdown]
# # **Step 11: Feature Visualizations**

# %%
# Survival by Family Size
sns.countplot(x='FamilySize', hue='Survived', data=df, palette='viridis')
plt.title('Survival by Family Size')
plt.xlabel('Family Size')
plt.ylabel('Count')
plt.legend(title='Survived')
plt.show()

# Survival by Title
sns.countplot(x='Title', hue='Survived', data=df, palette='Accent')
plt.title('Survival by Title')
plt.xlabel('Title')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Survived')
plt.show()

# Survival by Age Group
sns.countplot(x='AgeGroup', hue='Survived', data=df, palette='pastel')
plt.title('Survival by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.legend(title='Survived')
plt.show()

# %% [markdown]
# # **Step 12: Outlier Detection**

# %%
# Detecting Outliers in Age
sns.boxplot(y='Age', data=df, color='salmon')
plt.title('Age Outliers')
plt.ylabel('Age')
plt.show()

# Detecting Outliers in Fare
sns.boxplot(y='Fare', data=df, color='gold')
plt.title('Fare Outliers')
plt.ylabel('Fare')
plt.show()
